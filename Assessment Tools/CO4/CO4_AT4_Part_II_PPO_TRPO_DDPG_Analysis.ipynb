# %% [markdown]
# # CO4-AT4-Part II: SmartGrid Energy Dispatch RL Performance Analysis
# **Course Outcome 4 (CO4-AT4-Part II)**
# **Student Name**: L. Sanjay Kumar
# **Registration Number**: 192425226
# **Course**: REINFORCEMENT LEARNING (MLA0305)
#
# ### Aim:
# To conduct data interpretation and comparative evaluation of advanced policy optimization algorithms, PPO (Proximal Policy Optimization), TRPO (Trust Region Policy Optimization), and DDPG (Deep Deterministic Policy Gradient) based on sample efficiency, ratio clipping boundaries, and net cost savings using Python.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load Dataset
df = pd.read_csv('CO4_AT4_Part_II_SmartGrid_Dispatch_Dataset.csv')
print('Dataset Shape:', df.shape)
df.head()

# %%
# Render Summary Table 1 Statistics
df.describe().T

# %%
# Figure 1: Feature Correlation Heatmap
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Cambria']
fig, ax = plt.subplots(figsize=(8, 6))
ax.matshow(df.corr(numeric_only=True), cmap='Blues')
ax.set_title('SmartGrid Dataset Feature Correlation Heatmap', fontfamily='Cambria')
plt.show()
